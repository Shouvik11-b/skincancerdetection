# %%
import os,glob
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.callbacks import Callback,EarlyStopping
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import classification_report

# %%
file_path = 'train'

name_class = os.listdir(file_path)
name_class
# Out:
# ['benign', 'malignant']

# %%
filepaths = list(glob.glob(file_path+'/**/*.*'))

filepaths
# Out:
# ['train\\benign\\0.jpg',
#  'train\\benign\\1.jpg',
#  'train\\benign\\10.jpg',
#  'train\\benign\\100.jpg',
#  'train\\benign\\101.jpg',
#  'train\\benign\\102.jpg',
#  'train\\benign\\103.jpg',
#  'train\\benign\\104.jpg',
#  'train\\benign\\105.jpg',
#  'train\\benign\\106.jpg',
#  'train\\benign\\107.jpg',
#  'train\\benign\\108.jpg',
#  'train\\benign\\109.jpg',
#  'train\\benign\\11.jpg',
#  'train\\benign\\110.jpg',
#  'train\\benign\\111.jpg',
#  'train\\benign\\112.jpg',
#  'train\\benign\\113.jpg',
#  'train\\benign\\114.jpg',
#  'train\\benign\\115.jpg',
#  'train\\benign\\116.jpg',
#  'train\\benign\\117.jpg',
#  'train\\benign\\118.jpg',
#  'train\\benign\\119.jpg',
#  'train\\benign\\12.jpg',
#  'train\\benign\\120.jpg',
#  'train\\benign\\121.jpg',
#  'train\\benign\\122.jpg',
#  'train\\benign\\123.jpg',
#  'train\\benign\\124.jpg',
#  'train\\benign\\125.jpg',
#  'train\\benign\\126.jpg',
#  'train\\benign\\127.jpg',
#  'train\\benign\\128.jpg',
#  'train\\benign\\129.jpg',
#  'train\\benign\\13.jpg',
#  'train\\benign\\130.jpg',
#  'train\\benign\\131.jpg',
#  'train\\benign\\132.jpg',
#  'train\\benign\\133.jpg',
#  'train\\benign\\134.jpg',
#  'train\\benign\\135.jpg',
#  'train\\benign\\136.jpg',
#  'train\\benign\\137.jpg',
#  'train\\benign\\138.jpg',
#  'train\\benign\\139.jpg',
#  'train\\benign\\14.jpg',
#  'train\\benign\\140.jpg',
#  'train\\benign\\141.jpg',
#  'train\\benign\\142.jpg',
#  'train\\benign\\143.jpg',
#  'train\\benign\\144.jpg',
#  'train\\benign\\145.jpg',
#  'train\\benign\\146.jpg',
#  'train\\benign\\147.jpg',
#  'train\\benign\\148.jpg',
#  'train\\benign\\149.jpg',
#  'train\\benign\\15.jpg',
#  'train\\benign\\150.jpg',
#  'train\\benign\\151.jpg',
#  'train\\benign\\152.jpg',
#  'train\\benign\\153.jpg',
#  'train\\benign\\154.jpg',
#  'train\\benign\\155.jpg',
#  'train\\benign\\156.jpg',
#  'train\\benign\\157.jpg',
#  'train\\benign\\158.jpg',
#  'train\\benign\\159.jpg',
#  'train\\benign\\16.jpg',
#  'train\\benign\\160.jpg',
#  'train\\benign\\161.jpg',
#  'train\\benign\\162.jpg',
#  'train\\benign\\163.jpg',
#  'train\\benign\\164.jpg',
#  'train\\benign\\165.jpg',
#  'train\\benign\\166.jpg',
#  'train\\benign\\167.jpg',
#  'train\\benign\\168.jpg',
#  'train\\benign\\169.jpg',
#  'train\\benign\\17.jpg',
#  'train\\benign\\170.jpg',
#  'train\\benign\\171.jpg',
#  'train\\benign\\172.jpg',
#  'train\\benign\\173.jpg',
#  'train\\benign\\174.jpg',
#  'train\\benign\\175.jpg',
#  'train\\benign\\176.jpg',
#  'train\\benign\\177.jpg',
#  'train\\benign\\178.jpg',
#  'train\\benign\\179.jpg',
#  'train\\benign\\18.jpg',
#  'train\\benign\\180.jpg',
#  'train\\benign\\181.jpg',
#  'train\\benign\\182.jpg',
#  'train\\benign\\183.jpg',
#  'train\\benign\\184.jpg',
#  'train\\benign\\185.jpg',
#  'train\\benign\\186.jpg',
#  'train\\benign\\187.jpg',
#  'train\\benign\\188.jpg',
#  'train\\benign\\189.jpg',
#  'train\\benign\\19.jpg',
#  'train\\benign\\190.jpg',
#  'train\\benign\\191.jpg',
#  'train\\benign\\192.jpg',
#  'train\\benign\\193.jpg',
#  'train\\benign\\194.jpg',
#  'train\\benign\\195.jpg',
#  'train\\benign\\196.jpg',
#  'train\\benign\\197.jpg',
#  'train\\benign\\198.jpg',
#  'train\\benign\\199.jpg',
#  'train\\benign\\2.jpg',
#  'train\\benign\\20.jpg',
#  'train\\benign\\200.jpg',
#  'train\\benign\\201.jpg',
#  'train\\benign\\202.jpg',
#  'train\\benign\\203.jpg',
#  'train\\benign\\204.jpg',
#  'train\\benign\\205.jpg',
#  'train\\benign\\206.jpg',
#  'train\\benign\\207.jpg',
#  'train\\benign\\208.jpg',
#  'train\\benign\\209.jpg',
#  'train\\benign\\21.jpg',
#  'train\\benign\\210.jpg',
#  'train\\benign\\211.jpg',
#  'train\\benign\\212.jpg',
#  'train\\benign\\213.jpg',
#  'train\\benign\\214.jpg',
#  'train\\benign\\215.jpg',
#  'train\\benign\\216.jpg',
#  'train\\benign\\217.jpg',
#  'train\\benign\\218.jpg',
#  'train\\benign\\219.jpg',
#  'train\\benign\\22.jpg',
#  'train\\benign\\220.jpg',
#  'train\\benign\\221.jpg',
#  'train\\benign\\222.jpg',
#  'train\\benign\\223.jpg',
#  'train\\benign\\224.jpg',
#  'train\\benign\\225.jpg',
#  'train\\benign\\226.jpg',
#  'train\\benign\\227.jpg',
#  'train\\benign\\228.jpg',
#  'train\\benign\\229.jpg',
#  'train\\benign\\23.jpg',
#  'train\\benign\\230.jpg',
#  'train\\benign\\231.jpg',
#  'train\\benign\\232.jpg',
#  'train\\benign\\233.jpg',
#  'train\\benign\\234.jpg',
#  'train\\benign\\235.jpg',
#  'train\\benign\\236.jpg',
#  'train\\benign\\237.jpg',
#  'train\\benign\\238.jpg',
#  'train\\benign\\239.jpg',
#  'train\\benign\\24.jpg',
#  'train\\benign\\240.jpg',
#  'train\\benign\\241.jpg',
#  'train\\benign\\242.jpg',
#  'train\\benign\\243.jpg',
#  'train\\benign\\244.jpg',
#  'train\\benign\\245.jpg',
#  'train\\benign\\246.jpg',
#  'train\\benign\\247.jpg',
#  'train\\benign\\248.jpg',
#  'train\\benign\\249.jpg',
#  'train\\benign\\25.jpg',
#  'train\\benign\\250.jpg',
#  'train\\benign\\251.jpg',
#  'train\\benign\\252.jpg',
#  'train\\benign\\253.jpg',
#  'train\\benign\\254.jpg',
#  'train\\benign\\255.jpg',
#  'train\\benign\\256.jpg',
#  'train\\benign\\257.jpg',
#  'train\\benign\\258.jpg',
#  'train\\benign\\259.jpg',
#  'train\\benign\\26.jpg',
#  'train\\benign\\260.jpg',
#  'train\\benign\\261.jpg',
#  'train\\benign\\262.jpg',
#  'train\\benign\\263.jpg',
#  'train\\benign\\264.jpg',
#  'train\\benign\\265.jpg',
#  'train\\benign\\266.jpg',
#  'train\\benign\\267.jpg',
#  'train\\benign\\268.jpg',
#  'train\\benign\\269.jpg',
#  'train\\benign\\27.jpg',
#  'train\\benign\\270.jpg',
#  'train\\benign\\271.jpg',
#  'train\\benign\\272.jpg',
#  'train\\benign\\273.jpg',
#  'train\\benign\\274.jpg',
#  'train\\benign\\275.jpg',
#  'train\\benign\\276.jpg',
#  'train\\benign\\277.jpg',
#  'train\\benign\\278.jpg',
#  'train\\benign\\279.jpg',
#  'train\\benign\\28.jpg',
#  'train\\benign\\280.jpg',
#  'train\\benign\\281.jpg',
#  'train\\benign\\282.jpg',
#  'train\\benign\\283.jpg',
#  'train\\benign\\284.jpg',
#  'train\\benign\\285.jpg',
#  'train\\benign\\286.jpg',
#  'train\\benign\\287.jpg',
#  'train\\benign\\288.jpg',
#  'train\\benign\\289.jpg',
#  'train\\benign\\29.jpg',
#  'train\\benign\\290.jpg',
#  'train\\benign\\291.jpg',
#  'train\\benign\\292.jpg',
#  'train\\benign\\293.jpg',
#  'train\\benign\\294.jpg',
#  'train\\benign\\295.jpg',
#  'train\\benign\\296.jpg',
#  'train\\benign\\297.jpg',
#  'train\\benign\\298.jpg',
#  'train\\benign\\299.jpg',
#  'train\\benign\\3.jpg',
#  'train\\benign\\30.jpg',
#  'train\\benign\\300.jpg',
#  'train\\benign\\301.jpg',
#  'train\\benign\\302.jpg',
#  'train\\benign\\303.jpg',
#  'train\\benign\\304.jpg',
#  'train\\benign\\305.jpg',
#  'train\\benign\\306.jpg',
#  'train\\benign\\307.jpg',
#  'train\\benign\\308.jpg',
#  'train\\benign\\309.jpg',
#  'train\\benign\\31.jpg',
#  'train\\benign\\310.jpg',
#  'train\\benign\\311.jpg',
#  'train\\benign\\312.jpg',
#  'train\\benign\\313.jpg',
#  'train\\benign\\314.jpg',
#  'train\\benign\\315.jpg',
#  'train\\benign\\316.jpg',
#  'train\\benign\\317.jpg',
#  'train\\benign\\318.jpg',
#  'train\\benign\\319.jpg',
#  'train\\benign\\32.jpg',
#  'train\\benign\\320.jpg',
#  'train\\benign\\321.jpg',
#  'train\\benign\\322.jpg',
#  'train\\benign\\323.jpg',
#  'train\\benign\\324.jpg',
#  'train\\benign\\325.jpg',
#  'train\\benign\\326.jpg',
#  'train\\benign\\327.jpg',
#  'train\\benign\\328.jpg',
#  'train\\benign\\329.jpg',
#  'train\\benign\\33.jpg',
#  'train\\benign\\330.jpg',
#  'train\\benign\\331.jpg',
#  'train\\benign\\332.jpg',
#  'train\\benign\\333.jpg',
#  'train\\benign\\334.jpg',
#  'train\\benign\\335.jpg',
#  'train\\benign\\336.jpg',
#  'train\\benign\\337.jpg',
#  'train\\benign\\338.jpg',
#  'train\\benign\\339.jpg',
#  'train\\benign\\34.jpg',
#  'train\\benign\\340.jpg',
#  'train\\benign\\341.jpg',
#  'train\\benign\\342.jpg',
#  'train\\benign\\343.jpg',
#  'train\\benign\\344.jpg',
#  'train\\benign\\345.jpg',
#  'train\\benign\\346.jpg',
#  'train\\benign\\347.jpg',
#  'train\\benign\\348.jpg',
#  'train\\benign\\349.jpg',
#  'train\\benign\\35.jpg',
#  'train\\benign\\350.jpg',
#  'train\\benign\\351.jpg',
#  'train\\benign\\352.jpg',
#  'train\\benign\\353.jpg',
#  'train\\benign\\354.jpg',
#  'train\\benign\\355.jpg',
#  'train\\benign\\356.jpg',
#  'train\\benign\\357.jpg',
#  'train\\benign\\358.jpg',
#  'train\\benign\\359.jpg',
#  'train\\benign\\36.jpg',
#  'train\\benign\\360.jpg',
#  'train\\benign\\37.jpg',
#  'train\\benign\\38.jpg',
#  'train\\benign\\39.jpg',
#  'train\\benign\\4.jpg',
#  'train\\benign\\40.jpg',
#  'train\\benign\\41.jpg',
#  'train\\benign\\42.jpg',
#  'train\\benign\\43.jpg',
#  'train\\benign\\44.jpg',
#  'train\\benign\\45.jpg',
#  'train\\benign\\46.jpg',
#  'train\\benign\\47.jpg',
#  'train\\benign\\48.jpg',
#  'train\\benign\\49.jpg',
#  'train\\benign\\5.jpg',
#  'train\\benign\\50.jpg',
#  'train\\benign\\51.jpg',
#  'train\\benign\\52.jpg',
#  'train\\benign\\53.jpg',
#  'train\\benign\\54.jpg',
#  'train\\benign\\55.jpg',
#  'train\\benign\\56.jpg',
#  'train\\benign\\57.jpg',
#  'train\\benign\\58.jpg',
#  'train\\benign\\59.jpg',
#  'train\\benign\\6.jpg',
#  'train\\benign\\60.jpg',
#  'train\\benign\\61.jpg',
#  'train\\benign\\62.jpg',
#  'train\\benign\\63.jpg',
#  'train\\benign\\64.jpg',
#  'train\\benign\\65.jpg',
#  'train\\benign\\66.jpg',
#  'train\\benign\\67.jpg',
#  'train\\benign\\68.jpg',
#  'train\\benign\\69.jpg',
#  'train\\benign\\7.jpg',
#  'train\\benign\\70.jpg',
#  'train\\benign\\71.jpg',
#  'train\\benign\\72.jpg',
#  'train\\benign\\73.jpg',
#  'train\\benign\\74.jpg',
#  'train\\benign\\75.jpg',
#  'train\\benign\\76.jpg',
#  'train\\benign\\77.jpg',
#  'train\\benign\\78.jpg',
#  'train\\benign\\79.jpg',
#  'train\\benign\\8.jpg',
#  'train\\benign\\80.jpg',
#  'train\\benign\\81.jpg',
#  'train\\benign\\82.jpg',
#  'train\\benign\\83.jpg',
#  'train\\benign\\84.jpg',
#  'train\\benign\\85.jpg',
#  'train\\benign\\86.jpg',
#  'train\\benign\\87.jpg',
#  'train\\benign\\88.jpg',
#  'train\\benign\\89.jpg',
#  'train\\benign\\9.jpg',
#  'train\\benign\\90.jpg',
#  'train\\benign\\91.jpg',
#  'train\\benign\\92.jpg',
#  'train\\benign\\93.jpg',
#  'train\\benign\\94.jpg',
#  'train\\benign\\95.jpg',
#  'train\\benign\\96.jpg',
#  'train\\benign\\97.jpg',
#  'train\\benign\\98.jpg',
#  'train\\benign\\99.jpg',
#  'train\\malignant\\0.jpg',
#  'train\\malignant\\1.jpg',
#  'train\\malignant\\10.jpg',
#  'train\\malignant\\100.jpg',
#  'train\\malignant\\101.jpg',
#  'train\\malignant\\102.jpg',
#  'train\\malignant\\103.jpg',
#  'train\\malignant\\104.jpg',
#  'train\\malignant\\105.jpg',
#  'train\\malignant\\106.jpg',
#  'train\\malignant\\107.jpg',
#  'train\\malignant\\108.jpg',
#  'train\\malignant\\109.jpg',
#  'train\\malignant\\11.jpg',
#  'train\\malignant\\110.jpg',
#  'train\\malignant\\111.jpg',
#  'train\\malignant\\112.jpg',
#  'train\\malignant\\113.jpg',
#  'train\\malignant\\114.jpg',
#  'train\\malignant\\115.jpg',
#  'train\\malignant\\116.jpg',
#  'train\\malignant\\117.jpg',
#  'train\\malignant\\118.jpg',
#  'train\\malignant\\119.jpg',
#  'train\\malignant\\12.jpg',
#  'train\\malignant\\120.jpg',
#  'train\\malignant\\121.jpg',
#  'train\\malignant\\122.jpg',
#  'train\\malignant\\123.jpg',
#  'train\\malignant\\124.jpg',
#  'train\\malignant\\125.jpg',
#  'train\\malignant\\126.jpg',
#  'train\\malignant\\127.jpg',
#  'train\\malignant\\128.jpg',
#  'train\\malignant\\129.jpg',
#  'train\\malignant\\13.jpg',
#  'train\\malignant\\130.jpg',
#  'train\\malignant\\131.jpg',
#  'train\\malignant\\132.jpg',
#  'train\\malignant\\133.jpg',
#  'train\\malignant\\134.jpg',
#  'train\\malignant\\135.jpg',
#  'train\\malignant\\136.jpg',
#  'train\\malignant\\137.jpg',
#  'train\\malignant\\138.jpg',
#  'train\\malignant\\139.jpg',
#  'train\\malignant\\14.jpg',
#  'train\\malignant\\140.jpg',
#  'train\\malignant\\141.jpg',
#  'train\\malignant\\142.jpg',
#  'train\\malignant\\143.jpg',
#  'train\\malignant\\144.jpg',
#  'train\\malignant\\145.jpg',
#  'train\\malignant\\146.jpg',
#  'train\\malignant\\147.jpg',
#  'train\\malignant\\148.jpg',
#  'train\\malignant\\149.jpg',
#  'train\\malignant\\15.jpg',
#  'train\\malignant\\150.jpg',
#  'train\\malignant\\151.jpg',
#  'train\\malignant\\152.jpg',
#  'train\\malignant\\153.jpg',
#  'train\\malignant\\154.jpg',
#  'train\\malignant\\155.jpg',
#  'train\\malignant\\156.jpg',
#  'train\\malignant\\157.jpg',
#  'train\\malignant\\158.jpg',
#  'train\\malignant\\159.jpg',
#  'train\\malignant\\16.jpg',
#  'train\\malignant\\160.jpg',
#  'train\\malignant\\161.jpg',
#  'train\\malignant\\162.jpg',
#  'train\\malignant\\163.jpg',
#  'train\\malignant\\164.jpg',
#  'train\\malignant\\165.jpg',
#  'train\\malignant\\166.jpg',
#  'train\\malignant\\167.jpg',
#  'train\\malignant\\168.jpg',
#  'train\\malignant\\169.jpg',
#  'train\\malignant\\17.jpg',
#  'train\\malignant\\170.jpg',
#  'train\\malignant\\171.jpg',
#  'train\\malignant\\172.jpg',
#  'train\\malignant\\173.jpg',
#  'train\\malignant\\174.jpg',
#  'train\\malignant\\175.jpg',
#  'train\\malignant\\176.jpg',
#  'train\\malignant\\177.jpg',
#  'train\\malignant\\178.jpg',
#  'train\\malignant\\179.jpg',
#  'train\\malignant\\18.jpg',
#  'train\\malignant\\180.jpg',
#  'train\\malignant\\181.jpg',
#  'train\\malignant\\182.jpg',
#  'train\\malignant\\183.jpg',
#  'train\\malignant\\184.jpg',
#  'train\\malignant\\185.jpg',
#  'train\\malignant\\186.jpg',
#  'train\\malignant\\187.jpg',
#  'train\\malignant\\188.jpg',
#  'train\\malignant\\189.jpg',
#  'train\\malignant\\19.jpg',
#  'train\\malignant\\190.jpg',
#  'train\\malignant\\191.jpg',
#  'train\\malignant\\192.jpg',
#  'train\\malignant\\193.jpg',
#  'train\\malignant\\194.jpg',
#  'train\\malignant\\195.jpg',
#  'train\\malignant\\196.jpg',
#  'train\\malignant\\197.jpg',
#  'train\\malignant\\198.jpg',
#  'train\\malignant\\199.jpg',
#  'train\\malignant\\2.jpg',
#  'train\\malignant\\20.jpg',
#  'train\\malignant\\200.jpg',
#  'train\\malignant\\201.jpg',
#  'train\\malignant\\202.jpg',
#  'train\\malignant\\203.jpg',
#  'train\\malignant\\204.jpg',
#  'train\\malignant\\205.jpg',
#  'train\\malignant\\206.jpg',
#  'train\\malignant\\207.jpg',
#  'train\\malignant\\208.jpg',
#  'train\\malignant\\209.jpg',
#  'train\\malignant\\21.jpg',
#  'train\\malignant\\210.jpg',
#  'train\\malignant\\211.jpg',
#  'train\\malignant\\212.jpg',
#  'train\\malignant\\213.jpg',
#  'train\\malignant\\214.jpg',
#  'train\\malignant\\215.jpg',
#  'train\\malignant\\216.jpg',
#  'train\\malignant\\217.jpg',
#  'train\\malignant\\218.jpg',
#  'train\\malignant\\219.jpg',
#  'train\\malignant\\22.jpg',
#  'train\\malignant\\220.jpg',
#  'train\\malignant\\221.jpg',
#  'train\\malignant\\222.jpg',
#  'train\\malignant\\223.jpg',
#  'train\\malignant\\224.jpg',
#  'train\\malignant\\225.jpg',
#  'train\\malignant\\226.jpg',
#  'train\\malignant\\227.jpg',
#  'train\\malignant\\228.jpg',
#  'train\\malignant\\229.jpg',
#  'train\\malignant\\23.jpg',
#  'train\\malignant\\230.jpg',
#  'train\\malignant\\231.jpg',
#  'train\\malignant\\232.jpg',
#  'train\\malignant\\233.jpg',
#  'train\\malignant\\234.jpg',
#  'train\\malignant\\235.jpg',
#  'train\\malignant\\236.jpg',
#  'train\\malignant\\237.jpg',
#  'train\\malignant\\238.jpg',
#  'train\\malignant\\239.jpg',
#  'train\\malignant\\24.jpg',
#  'train\\malignant\\240.jpg',
#  'train\\malignant\\241.jpg',
#  'train\\malignant\\242.jpg',
#  'train\\malignant\\243.jpg',
#  'train\\malignant\\244.jpg',
#  'train\\malignant\\245.jpg',
#  'train\\malignant\\246.jpg',
#  'train\\malignant\\247.jpg',
#  'train\\malignant\\248.jpg',
#  'train\\malignant\\249.jpg',
#  'train\\malignant\\25.jpg',
#  'train\\malignant\\250.jpg',
#  'train\\malignant\\251.jpg',
#  'train\\malignant\\252.jpg',
#  'train\\malignant\\253.jpg',
#  'train\\malignant\\254.jpg',
#  'train\\malignant\\255.jpg',
#  'train\\malignant\\256.jpg',
#  'train\\malignant\\257.jpg',
#  'train\\malignant\\258.jpg',
#  'train\\malignant\\259.jpg',
#  'train\\malignant\\26.jpg',
#  'train\\malignant\\260.jpg',
#  'train\\malignant\\261.jpg',
#  'train\\malignant\\262.jpg',
#  'train\\malignant\\263.jpg',
#  'train\\malignant\\264.jpg',
#  'train\\malignant\\265.jpg',
#  'train\\malignant\\266.jpg',
#  'train\\malignant\\267.jpg',
#  'train\\malignant\\268.jpg',
#  'train\\malignant\\269.jpg',
#  'train\\malignant\\27.jpg',
#  'train\\malignant\\270.jpg',
#  'train\\malignant\\271.jpg',
#  'train\\malignant\\272.jpg',
#  'train\\malignant\\273.jpg',
#  'train\\malignant\\274.jpg',
#  'train\\malignant\\275.jpg',
#  'train\\malignant\\276.jpg',
#  'train\\malignant\\277.jpg',
#  'train\\malignant\\278.jpg',
#  'train\\malignant\\279.jpg',
#  'train\\malignant\\28.jpg',
#  'train\\malignant\\280.jpg',
#  'train\\malignant\\281.jpg',
#  'train\\malignant\\282.jpg',
#  'train\\malignant\\283.jpg',
#  'train\\malignant\\284.jpg',
#  'train\\malignant\\285.jpg',
#  'train\\malignant\\286.jpg',
#  'train\\malignant\\287.jpg',
#  'train\\malignant\\288.jpg',
#  'train\\malignant\\289.jpg',
#  'train\\malignant\\29.jpg',
#  'train\\malignant\\290.jpg',
#  'train\\malignant\\291.jpg',
#  'train\\malignant\\292.jpg',
#  'train\\malignant\\293.jpg',
#  'train\\malignant\\294.jpg',
#  'train\\malignant\\295.jpg',
#  'train\\malignant\\296.jpg',
#  'train\\malignant\\297.jpg',
#  'train\\malignant\\298.jpg',
#  'train\\malignant\\299.jpg',
#  'train\\malignant\\3.jpg',
#  'train\\malignant\\30.jpg',
#  'train\\malignant\\300.jpg',
#  'train\\malignant\\31.jpg',
#  'train\\malignant\\32.jpg',
#  'train\\malignant\\33.jpg',
#  'train\\malignant\\34.jpg',
#  'train\\malignant\\35.jpg',
#  'train\\malignant\\36.jpg',
#  'train\\malignant\\37.jpg',
#  'train\\malignant\\38.jpg',
#  'train\\malignant\\39.jpg',
#  'train\\malignant\\4.jpg',
#  'train\\malignant\\40.jpg',
#  'train\\malignant\\41.jpg',
#  'train\\malignant\\42.jpg',
#  'train\\malignant\\43.jpg',
#  'train\\malignant\\44.jpg',
#  'train\\malignant\\45.jpg',
#  'train\\malignant\\46.jpg',
#  'train\\malignant\\47.jpg',
#  'train\\malignant\\48.jpg',
#  'train\\malignant\\49.jpg',
#  'train\\malignant\\5.jpg',
#  'train\\malignant\\50.jpg',
#  'train\\malignant\\51.jpg',
#  'train\\malignant\\52.jpg',
#  'train\\malignant\\53.jpg',
#  'train\\malignant\\54.jpg',
#  'train\\malignant\\55.jpg',
#  'train\\malignant\\56.jpg',
#  'train\\malignant\\57.jpg',
#  'train\\malignant\\58.jpg',
#  'train\\malignant\\59.jpg',
#  'train\\malignant\\6.jpg',
#  'train\\malignant\\60.jpg',
#  'train\\malignant\\61.jpg',
#  'train\\malignant\\62.jpg',
#  'train\\malignant\\63.jpg',
#  'train\\malignant\\64.jpg',
#  'train\\malignant\\65.jpg',
#  'train\\malignant\\66.jpg',
#  'train\\malignant\\67.jpg',
#  'train\\malignant\\68.jpg',
#  'train\\malignant\\69.jpg',
#  'train\\malignant\\7.jpg',
#  'train\\malignant\\70.jpg',
#  'train\\malignant\\71.jpg',
#  'train\\malignant\\72.jpg',
#  'train\\malignant\\73.jpg',
#  'train\\malignant\\74.jpg',
#  'train\\malignant\\75.jpg',
#  'train\\malignant\\76.jpg',
#  'train\\malignant\\77.jpg',
#  'train\\malignant\\78.jpg',
#  'train\\malignant\\79.jpg',
#  'train\\malignant\\8.jpg',
#  'train\\malignant\\80.jpg',
#  'train\\malignant\\81.jpg',
#  'train\\malignant\\82.jpg',
#  'train\\malignant\\83.jpg',
#  'train\\malignant\\84.jpg',
#  'train\\malignant\\85.jpg',
#  'train\\malignant\\86.jpg',
#  'train\\malignant\\87.jpg',
#  'train\\malignant\\88.jpg',
#  'train\\malignant\\89.jpg',
#  'train\\malignant\\9.jpg',
#  'train\\malignant\\90.jpg',
#  'train\\malignant\\91.jpg',
#  'train\\malignant\\92.jpg',
#  'train\\malignant\\93.jpg',
#  'train\\malignant\\94.jpg',
#  'train\\malignant\\95.jpg',
#  'train\\malignant\\96.jpg',
#  'train\\malignant\\97.jpg',
#  'train\\malignant\\98.jpg',
#  'train\\malignant\\99.jpg']

# %%
labels = list(map(lambda x:os.path.split(os.path.split(x)[0])[1],filepaths))

labels
# Out:
# ['benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'benign',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant',
#  'malignant']

# %%
filepath = pd.Series(filepaths,name='filepath').astype(str)
labels = pd.Series(labels, name='Label')
data = pd.concat([filepath,labels],axis=1)
data = data.sample(frac= 1).reset_index(drop=True)

data.head()
# Out:
#                  filepath      Label
# 0    train\benign\297.jpg     benign
# 1  train\malignant\40.jpg  malignant
# 2    train\benign\275.jpg     benign
# 3   train\malignant\5.jpg  malignant
# 4    train\benign\131.jpg     benign

# %%
counts = data.Label.value_counts()
sns.barplot(x=counts.index,y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90)
# Out:
# (array([0, 1]), [Text(0, 0, 'benign'), Text(1, 0, 'malignant')])

# %%
train,test = train_test_split(data,test_size=0.25,random_state=42)

# %%
flg, axes = plt.subplots(nrows=5,ncols=3,figsize=(10,8),subplot_kw={'xticks':[],'yticks':[]})
for i,ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe = train,
    x_col='filepath',
    y_col='Label',
    target_size = (100,100),
    class_model = 'categorical',
    batch_size = 32,
    shuffle = True,
    seed = 42
)

valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=43
)

test_gen= test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 496 validated image filenames belonging to 2 classes.
# Found 166 validated image filenames belonging to 2 classes.
# Found 166 validated image filenames belonging to 2 classes.

# %%
w=100
h=100

pretrained_model = ResNet50(input_shape=(w,h,3),include_top=False,weights='imagenet',pooling='avg')

pretrained_model.trainable= False

# %%
inputs = pretrained_model.input

x = Dense(128,activation='relu')(pretrained_model.output)
x = Dense(128,activation='relu')(x)

outputs = Dense(2,activation='softmax')(x)

model = Model(inputs=inputs,outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks = [EarlyStopping(monitor='val_accuracy',
                              min_delta =0,
                              patience=2,
                              mode='auto'
)]

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=10
)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 18s 859ms/step - loss: 0.5644 - accuracy: 0.7601 - val_loss: 0.4473 - val_accuracy: 0.7530
# Epoch 2/10
# 16/16 [==============================] - 11s 670ms/step - loss: 0.3730 - accuracy: 0.8327 - val_loss: 0.3828 - val_accuracy: 0.8494
# Epoch 3/10
# 16/16 [==============================] - 11s 694ms/step - loss: 0.2432 - accuracy: 0.9153 - val_loss: 0.3557 - val_accuracy: 0.8253
# Epoch 4/10
# 16/16 [==============================] - 11s 668ms/step - loss: 0.1762 - accuracy: 0.9274 - val_loss: 0.3774 - val_accuracy: 0.8193
# Epoch 5/10
# 16/16 [==============================] - 11s 674ms/step - loss: 0.1281 - accuracy: 0.9698 - val_loss: 0.3799 - val_accuracy: 0.8072
# Epoch 6/10
# 16/16 [==============================] - 11s 668ms/step - loss: 0.0859 - accuracy: 0.9738 - val_loss: 0.3893 - val_accuracy: 0.8373
# Epoch 7/10
# 16/16 [==============================] - 11s 678ms/step - loss: 0.0663 - accuracy: 0.9839 - val_loss: 0.4666 - val_accuracy: 0.7952
# Epoch 8/10
# 16/16 [==============================] - 13s 814ms/step - loss: 0.0405 - accuracy: 0.9980 - val_loss: 0.4697 - val_accuracy: 0.8253
# Epoch 9/10
# 16/16 [==============================] - 12s 774ms/step - loss: 0.0271 - accuracy: 0.9940 - val_loss: 0.5593 - val_accuracy: 0.8133
# Epoch 10/10
# 16/16 [==============================] - 17s 1s/step - loss: 0.0331 - accuracy: 0.9899 - val_loss: 0.5067 - val_accuracy: 0.8434

# %%
model.save('model_resnet50.h5')

pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title('Accuracy')
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title('Loss')
plt.show()

# %%
results = model.evaluate(test_gen,verbose=0)

print('Test Loss: {:.5f}'.format(results[0]))
print('Test Accuracy: {:.2f}%'.format(results[1]*100))
# Out:
# Test Loss: 0.50669
# Test Accuracy: 84.34%

# %%
pred = model.predict(test_gen)
pred = np.argmax(pred,axis=1)

labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())

pred = [labels[k] for k in pred]
# Out:
# 6/6 [==============================] - 3s 448ms/step

# %%
y_test = list(test.Label)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.86      0.81      0.84        81
#    malignant       0.83      0.87      0.85        85
#
#     accuracy                           0.84       166
#    macro avg       0.84      0.84      0.84       166
# weighted avg       0.84      0.84      0.84       166

# %%
 fig,axes = plt.subplots(nrows=5,ncols=2,figsize=(12,8),
              subplot_kw={'xticks': [],'yticks': []})
    
for i,ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.filepath.iloc[i]))
    ax.set_title(f"True: {test.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()
